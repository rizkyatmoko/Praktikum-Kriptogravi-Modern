# %%
import time
from cryptography.hazmat.primitives.asymmetric import rsa, padding
from cryptography.hazmat.primitives import hashes

# =========================
# generate key
# =========================

start = time.time()

private_key = rsa.generate_private_key(
    public_exponent=65537,
    key_size=2048
)

end = time.time()

public_key = private_key.public_key()

print("Waktu generate key:", end - start)

# =========================
# pesan
# =========================

message = b"Belajar RSA pada praktikum kriptografi"

# =========================
# enkripsi
# =========================

ciphertext = public_key.encrypt(
    message,
    padding.OAEP(
        mgf=padding.MGF1(algorithm=hashes.SHA256()),
        algorithm=hashes.SHA256(),
        label=None
    )
)

print("Ciphertext:", ciphertext)
print("Ukuran ciphertext:", len(ciphertext))

# =========================
# dekripsi
# =========================

plaintext = private_key.decrypt(
    ciphertext,
    padding.OAEP(
        mgf=padding.MGF1(algorithm=hashes.SHA256()),
        algorithm=hashes.SHA256(),
        label=None
    )
)

print("Plaintext:", plaintext)
# Out:
# Waktu generate key: 0.06309723854064941
# Ciphertext: b'\x02c\x18\x82\x9aI\xa7\x1a\x80H)\x87\x84"\xca\xf3\xe0\x04Qj\xfbg\xc6?\xe6\x1a\x80z\xbe\'\x14\x05\x17\xd0\xf5^\xf3\xf4<\xde\x9b\xff\xa4d]\x04 t\xd8\xdfmP\x1bX\xac\x8d\x84w\xa2+\xfe\xd6\x19\xb6|\xc5\x90\r\x93/e\xd9\x10[\xf2\xe1X\xf4\xf9\xeat\x96`\x88\x1f\x15\x88\xca.\x8f\x93r\xf4\xf3j\xbe\x82\x04\x01\x9c!\x06\xe5F\x02\x1f\x19\x9b\xfe\xebG\xea,\t9\x94Zh\xa2\x13#M\xa7\xc7+\xdbPwq\x8e*\xcd\x8eA.\xe0g;\x97\xb1u`\xfcK\xd5+K\')"\xcb]>8e\x80\xc6y^\x06\xcd\xa0{\xbf\xa0\xb7YF\xb49\xffZ\x87qj]\x132q\xdf\xd6\x7f\xde\x93\x9a]-iS!0[R\ry&\xc6\xae\x9e\xd0k!\x80s\x95\xf9T\xe1\xfd\xf3\x1c\xa0i\xe1\xe0\x9c\xe2\x06\xaf\x0bO[\xa3\x02&\xb3z\xbe\xc6\xbc\xfcdWU\xf8\x15\x8c\x84\x82\x95\x07\xbc\xf2h+\xc84\xe0\xa4\xcd\x12e\xae"z\xf3'
# Ukuran ciphertext: 256
# Plaintext: b'Belajar RSA pada praktikum kriptografi'
